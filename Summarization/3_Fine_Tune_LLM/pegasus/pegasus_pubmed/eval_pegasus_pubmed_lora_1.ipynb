# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import

# %%
# !git clone https://github.com/google-research/bleurt.git
# %cd bleurt
# !pip install .
# Out:
# Cloning into 'bleurt'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 134 (delta 0), reused 17 (delta 0), pack-reused 116 (from 1)
# Receiving objects: 100% (134/134), 31.28 MiB | 43.69 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# /content/bleurt
# Processing /content/bleurt
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from BLEURT==0.0.2) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from BLEURT==0.0.2) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from BLEURT==0.0.2) (1.15.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from BLEURT==0.0.2) (2.18.0)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.11/dist-packages (from BLEURT==0.0.2) (1.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from tf-slim>=1.1->BLEURT==0.0.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->BLEURT==0.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->BLEURT==0.0.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->BLEURT==0.0.2) (2025.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (1.73.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->BLEURT==0.0.2) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->BLEURT==0.0.2) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->BLEURT==0.0.2) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->BLEURT==0.0.2) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->BLEURT==0.0.2) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->BLEURT==0.0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow->BLEURT==0.0.2) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow->BLEURT==0.0.2) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->BLEURT==0.0.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->BLEURT==0.0.2) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->BLEURT==0.0.2) (0.1.2)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (setup.py) ... done
#   Created wheel for BLEURT: filename=BLEURT-0.0.2-py3-none-any.whl size=16456766 sha256=d0b2a4705ea880260147bdd79490fb1c7f224f5e0e4905504d48b30eacdc89bd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qv7_d567/wheels/49/ab/73/9318ab38d4cd1c732bcea8335d3f8d7c0316c8d07b9084fa85
# Successfully built BLEURT
# Installing collected packages: BLEURT
# Successfully installed BLEURT-0.0.2

# %%
# !pip install -q evaluate rouge_score bert-score
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 100.0 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
import json
import time
import os
import pandas as pd
import numpy as np
import re
from copy import deepcopy

# %%
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
# !python -m unittest bleurt.score_test
# !python -m unittest bleurt.score_not_eager_test
# !python -m unittest bleurt.finetune_test
# !python -m unittest bleurt.score_files_test

# %%
from bleurt import score
from evaluate import load as load_metric

# %%
rouge = load_metric("rouge")
bertscore = load_metric("bertscore")
bleurt = load_metric("bleurt", module_type="metric")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/5.20k [00:00<?, ?B/s]
# WARNING:evaluate_modules.metrics.evaluate-metric--bleurt.98e148b2f8c4a88aba5037e4e0e90c9fd9ec35dc37a054ded8cfef0fa801ffab.bleurt:Using default BLEURT-Base checkpoint for sequence maximum length 128. You can use a bigger model for better results with e.g.: evaluate.load('bleurt', 'bleurt-large-512').
# Downloading data:   0%|          | 0.00/405M [00:00<?, ?B/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Load generations

# %%
fine_tune_path = '/content/drive/MyDrive/ClinicalNotesGen/Summarization/3_Fine_Tune_LLM'
model_name = 'pegasus' # ADJUST
sub_model_name = 'pegasus_pubmed' # ADJUST
checkpoints_dir = f"{fine_tune_path}/{model_name}/{sub_model_name}/lora_1" # ADJUST
checkpoints_path = f"{checkpoints_dir}/checkpoints"
final_checkpoints_path = f"{checkpoints_dir}/final_checkpoints"
eval_path = f"{checkpoints_dir}/eval_{sub_model_name}.csv"

# %%
eval_path
# Out:
# '/content/drive/MyDrive/ClinicalNotesGen/Summarization/3_Fine_Tune_LLM/pegasus/pegasus_pubmed/lora_1/eval_pegasus_pubmed.csv'

# %%
checkpoints_dir
# Out:
# '/content/drive/MyDrive/ClinicalNotesGen/Summarization/3_Fine_Tune_LLM/pegasus/pegasus_pubmed/lora_1'

# %%
test_soap_50_df = pd.read_csv(f"{checkpoints_dir}/test_soap_50.csv")
# test_soap_50_100_df = pd.read_csv(f"{checkpoints_dir}/test_soap_50_100.csv")
# # train_soap_50_df = pd.read_csv(f"{checkpoints_dir}/train_soap_50.csv")
# mts_50_df = pd.read_csv(f"{checkpoints_dir}/mts_50.csv")
# aci_50_df = pd.read_csv(f"{checkpoints_dir}/aci_50.csv")

# %%
print(len(test_soap_50_df))
test_soap_50_df.head(3)
# Out:
# 50
#                                             dialogue  \
# 0  Doctor: Hello, can you please tell me about yo...
# 1  Doctor: Hello, I understand that you're a 7-ye...
# 2  Doctor: Hello, we've received your results fro...
#
#                                       reference_note  \
# 0  S: The patient, a flooring installer with no s...
# 1  S: The patient is a 7-year-old boy with congen...
# 2  S: The patient reported undergoing an ultrasou...
#
#                              fine_tuned_model_output
# 0  S: The patient, a flooring installer, reports ...
# 1  S: The patient is a 7-year-old boy with congen...
# 2  S: The patient reports a single thyroid nodule...

# %% [markdown]
# # Evaluate on MTS-Dialog

# %% [markdown]
# ## Testing

# %%
def evaluate_clinical_summary(generated_text: str, reference_text: str) -> dict:
    predictions = [generated_text]
    references = [reference_text]

    # ROUGE
    rouge_scores = rouge.compute(predictions=predictions, references=references, use_stemmer=True)

    # BERTScore
    bert_scores = bertscore.compute(predictions=predictions, references=references, lang="en")
    bert_precision = sum(bert_scores['precision']) / len(bert_scores['precision'])
    bert_recall = sum(bert_scores['recall']) / len(bert_scores['recall'])
    bert_f1 = sum(bert_scores['f1']) / len(bert_scores['f1'])

    # BLEURT
    bleurt_score = bleurt.compute(predictions=predictions, references=references)['scores'][0]

    # # QuestEval
    # questeval_score = questeval.compute(hypothesis=generated_text, reference=reference_text, do_weighing=False)['questeval_score']

    return {
        "ROUGE-1": round(rouge_scores['rouge1'], 4),
        "ROUGE-2": round(rouge_scores['rouge2'], 4),
        "ROUGE-L": round(rouge_scores['rougeL'], 4),
        "ROUGE-LSum": round(rouge_scores['rougeLsum'], 4),
        "BERTScore-P": round(bert_precision, 4),
        "BERTScore-R": round(bert_recall, 4),
        "BERTScore-F1": round(bert_f1, 4),
        "BLEURT": round(bleurt_score, 4),
        # "QuestEval": round(questeval_score, 4)
    }

# %%
evaluate_clinical_summary("This is a test", "This is a test")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# {'ROUGE-1': np.float64(1.0),
#  'ROUGE-2': np.float64(1.0),
#  'ROUGE-L': np.float64(1.0),
#  'ROUGE-LSum': np.float64(1.0),
#  'BERTScore-P': 1.0,
#  'BERTScore-R': 1.0,
#  'BERTScore-F1': 1.0,
#  'BLEURT': 1.0118}

# %%
test_soap_50_df.iloc[0]["reference_note"]
# Out:
# "S: The patient, a flooring installer with no significant past medical history, presents with painless blurry vision in the right eye for one week, intermittent fevers, headaches, body aches, and a nonpruritic maculopapular rash on the lower legs for six months. The patient also reports an isolated episode of left knee and testicular swelling in the past but denies any neck stiffness, nausea, vomiting, Raynaud's phenomenon, oral ulcerations, chest pain, shortness of breath, abdominal pain, or photosensitivity. No history of exposure to toxic substances or habits related to smoking, drinking, or illicit drug use.\nO: Vital signs are normal. Physical examination reveals bilateral papilledema, greater optic nerve erythema in the right eye, a right inferior nasal quadrant visual field defect, and a right afferent pupillary defect. Muscle strength, reflexes, and sensation to light touch, pinprick, vibration, and proprioception are intact. A maculopapular rash is noted on bilateral lower extremities. Lab findings include microcytic anemia (Hemoglobin: 11.6 gm/dL, Hematocrit: 35.3%, MCV: 76.9 fL), hyponatremia (Sodium: 133 mmol/L), elevated ESR (33 mm/hr), and CRP (13.3 mg/L). Urinalysis is normal. Lumbar puncture shows clear fluid, 2 RBCs/µL, and 56 WBCs/µL.\nA: The patient's symptoms and findings suggest a possible inflammatory or infectious process affecting multiple systems, including the central nervous system, as indicated by papilledema and abnormal lumbar puncture results. Differential diagnoses could include autoimmune conditions, infectious diseases, or other systemic inflammatory disorders. The presence of optic nerve involvement and systemic symptoms necessitates further investigation to narrow down the causes.\nP: Plan to conduct additional diagnostic tests to explore underlying causes, including imaging studies and specific serological tests. Consultation with a neurologist and possibly a rheumatologist or infectious disease specialist is recommended. Monitor the patient's symptoms closely and provide supportive care as needed. Educate the patient about the findings and the importance of follow-up for further evaluation and management. Ensure the patient understands the potential seriousness of the symptoms and the need for thorough investigation and possibly long-term management."

# %%
test_soap_50_df.iloc[0]["fine_tuned_model_output"]
# Out:
# "S: The patient, a flooring installer, reports painless blurry vision in the right eye for a week, intermittent fevers, headache, body aches, and a nonpruritic maculopapular rash on the lower legs for the past 6 months. He denies any toxic substances, smoking, drinking, or illicit drug use. He also reports an isolated episode of left knee swelling and testicular swelling in the past. O: Vital signs were normal. Physical examination revealed bilateral papilledema and optic nerve in the right eye, with a right inferior nasal quadrant visual field defect and a right a pupillary defect. Muscle strength and reflexes were normal. Muscle strength and reflexes were intact. Laboratory findings included microcytism with a magnitude of 11.6 g/dL, hematocrit of 35.3%, and mean corpuscular volume of 76.9 fL. ESR was elevated at 33 mm/hr, and C-reactive protein (CRP) was elevated at 13.3 mg/L. A: The primary diagnosis is a systemic inflammatory process, likely infectious, with potential implications for the patient's symptoms. Differential diagnoses could include other causes of symptoms, such as a viral infection or a bacterial infection. The prognosis depends on the outcome of further tests and management. P: The management plan includes close monitoring of the patient's condition and the patient's symptoms. Regular follow-up appointments will be scheduled to assess the extent of the symptoms and manage any potential complications. The patient will be educated on the importance of reporting any new symptoms or concerns immediately."

# %%
evaluate_clinical_summary(test_soap_50_df.iloc[0]["reference_note"], test_soap_50_df.iloc[0]["fine_tuned_model_output"])
# Out:
# {'ROUGE-1': np.float64(0.6339),
#  'ROUGE-2': np.float64(0.3639),
#  'ROUGE-L': np.float64(0.4508),
#  'ROUGE-LSum': np.float64(0.4542),
#  'BERTScore-P': 0.8745,
#  'BERTScore-R': 0.9129,
#  'BERTScore-F1': 0.8933,
#  'BLEURT': 0.3116}

# %%
evaluate_clinical_summary(test_soap_50_df.iloc[1]["reference_note"], test_soap_50_df.iloc[1]["fine_tuned_model_output"])
# Out:
# {'ROUGE-1': np.float64(0.5355),
#  'ROUGE-2': np.float64(0.2667),
#  'ROUGE-L': np.float64(0.4265),
#  'ROUGE-LSum': np.float64(0.4502),
#  'BERTScore-P': 0.8944,
#  'BERTScore-R': 0.8601,
#  'BERTScore-F1': 0.8769,
#  'BLEURT': 0.1616}

# %% [markdown]
# ## Sequential

# %%
def evaluate_sequentially(df):
    results = []

    for idx, sample in tqdm(df.iterrows(), total=len(df), desc="Evaluating"):
        dialogue = sample["dialogue"]
        reference_summary = sample["reference summary"]
        generated_summary = sample["generated summary"]

        metrics = evaluate_clinical_summary(generated_summary, reference_summary)

        results.append({
            "dialogue": dialogue,
            "reference_summary": reference_summary,
            "generated_summary": generated_summary,
            **metrics
        })

    return pd.DataFrame(results)

# %%
eval_test_soap_50_df = evaluate_sequentially(test_soap_50_df)
eval_test_soap_50_df.to_csv(f"{checkpoints_dir}/eval_test_soap_50.csv", index=False)

# %% [markdown]
# ## Parallel

# %%
# Parallel
def evaluate_in_batch(df, batch_size=16):
    results = []

    for start in tqdm(range(0, len(df), batch_size), desc="Evaluating in batches"):
        batch = df.iloc[start:start+batch_size]
        preds = batch["fine_tuned_model_output"].tolist()
        refs = batch["reference_note"].tolist()
        diags = batch["dialogue"].tolist()

        # Compute metrics
        # rouge_scores = rouge.compute(predictions=preds, references=refs, use_stemmer=True)
        bert_scores = bertscore.compute(predictions=preds, references=refs, lang="en", device="cuda")
        bleurt_scores = bleurt.compute(predictions=preds, references=refs)

        for i in range(len(preds)):
          # ROUGE must be computed per example
            rouge_score = rouge.compute(predictions=[preds[i]], references=[refs[i]], use_stemmer=True)

            results.append({
                "dialogue": diags[i],
                "reference_summary": refs[i],
                "generated_summary": preds[i],
                "ROUGE-1": round(rouge_score['rouge1'], 4),
                "ROUGE-2": round(rouge_score['rouge2'], 4),
                "ROUGE-L": round(rouge_score['rougeL'], 4),
                "ROUGE-LSum": round(rouge_score['rougeLsum'], 4),
                "BERTScore-P": round(bert_scores['precision'][i], 4),
                "BERTScore-R": round(bert_scores['recall'][i], 4),
                "BERTScore-F1": round(bert_scores['f1'][i], 4),
                "BLEURT": round(bleurt_scores['scores'][i], 4),
            })

    return pd.DataFrame(results)

# %%
eval_test_soap_50_df = evaluate_in_batch(test_soap_50_df, batch_size=16)
eval_test_soap_50_df.to_csv(f"{checkpoints_dir}/eval_test_soap_50.csv", index=False)
# Out:
# Evaluating in batches: 100%|██████████| 4/4 [00:10<00:00,  2.71s/it]

# %%
eval_test_soap_50_df
# Out:
#                                              dialogue  \
# 0   Doctor: Hello, can you please tell me about yo...
# 1   Doctor: Hello, I understand that you're a 7-ye...
# 2   Doctor: Hello, we've received your results fro...
# 3   Doctor: Hello, can you tell me what brought yo...
# 4   Doctor: Hello, I understand that you have been...
# 5   Doctor: Hello, how can I help you today?\nPati...
# 6   Doctor: Hi there, I see you've presented with ...
# 7   Doctor: Hello, I heard you have a 6-month hist...
# 8   Doctor: Hi there, can you please tell me about...
# 9   Doctor: Hello, how can I help you today?\nPati...
# 10  Doctor: Hello, how can I help you today?\nPati...
# 11  Doctor: Hello, how can I help you today?\nPati...
# 12  Doctor: Hello, how can I help you today?\nPati...
# 13  Doctor: Hello, I see you have a history of cho...
# 14  Doctor: Hello, I received your medical records...
# 15  Doctor: Hello, I see that you are a 53-year-ol...
# 16  Doctor: Good morning! How can I help you today...
# 17  Doctor: Hello, I understand you are a 64-year-...
# 18  Doctor: Hello, how can I help you today?\nPati...
# 19  Doctor: Hi there, I understand you've been exp...
# 20  Doctor: Hello, I see that you've come in today...
# 21  Doctor: Good morning! What brings you in today...
# 22  Doctor: Hi there! I see you've presented with ...
# 23  Doctor: Hello, I wanted to discuss your curren...
# 24  Doctor: Hello, I see you've presented to the R...
# 25  Doctor: Hello, how can I help you today?\nPati...
# 26  Doctor: Hi there, I understand you originally ...
# 27  Doctor: Congratulations on your newborn baby g...
# 28  Doctor: Hello, how can I help you today?\nPati...
# 29  Doctor: Hello PT, how can I help you today?\nP...
# 30  Doctor: Hello, how can I help you today?\nPati...
# 31  Doctor: Hello, I understand you have a past me...
# 32  Doctor: Hello, can you please tell me about yo...
# 33  Doctor: Hello, I understand you have a history...
# 34  Doctor: Hi there, I see you've been admitted f...
# 35  Doctor: Hi there, how can I help you today?\nP...
# 36  Doctor: Hello, I see you've been admitted to t...
# 37  Doctor: Hello, I see that you're a 50-year-old...
# 38  Doctor: Hello, I see in your records that you'...
# 39  Doctor: Hello, thank you for coming in today. ...
# 40  Doctor: Hello, I understand you've been referr...
# 41  Doctor: Hi there, I'm the pediatric endocrinol...
# 42  Doctor: Hello, I see that you're a 72-year old...
# 43  Doctor: Hello! I understand that you've been r...
# 44  Doctor: Hello, I see you have a complicated ca...
# 45  Doctor: Hello, we have a 60-year-old white Bri...
# 46  Doctor: Hello, I understand you have a history...
# 47  Doctor: Hi there, I see you've presented with ...
# 48  Doctor: Hello, I see you're a 36-year-old woma...
# 49  Doctor: Hello, I'm Dr. Smith. Can you please t...
#
#                                     reference_summary  \
# 0   S: The patient, a flooring installer with no s...
# 1   S: The patient is a 7-year-old boy with congen...
# 2   S: The patient reported undergoing an ultrasou...
# 3   S: The patient reports a progressive headache,...
# 4   S: The patient, a post-liver transplant recipi...
# 5   S: The patient, a non-smoker and engineer, rep...
# 6   S: The patient presented with body weight loss...
# 7   S: The patient reports a 6-month history of sw...
# 8   S: The patient, a male with a history of prost...
# 9   S: The patient is a 76-year-old woman presenti...
# 10  S: The patient, a female with a history of HHH...
# 11  S: The patient is a 36-year-old gravida 2, par...
# 12  S: The patient, a 34-year-old male, presented ...
# 13  S: The patient reports experiencing bothersome...
# 14  S: 50-year-old African American female present...
# 15  S: The patient is a 53-year-old woman with a h...
# 16  S: The patient is a 70-year-old woman who pres...
# 17  S: The patient is a 64-year-old postmenopausal...
# 18  S: The patient reports experiencing pain and s...
# 19  S: The patient reports difficulties with atten...
# 20  S: Patient presents with worsening dyspnea, co...
# 21  S: The patient, a 34-year-old female, presents...
# 22  S: The patient reports persistent hoarseness a...
# 23  S: The patient reported a history of a strangu...
# 24  S: The patient, who has a history of beta thal...
# 25  S: The patient, a known case of dyslipidemia a...
# 26  S: The patient, who previously underwent lapar...
# 27  S: The patient is a newborn female delivered a...
# 28  S: The patient is a 48-year-old woman who repo...
# 29  S: Patient reports recurrent amnesia upon waki...
# 30  S: Patient reports constant blurry vision in t...
# 31  S: The patient, with a history of multiple chr...
# 32  S: The patient, a female with a history of mul...
# 33  S: The patient, a 13-year-old with a history o...
# 34  S: The patient, admitted for anemia and thromb...
# 35  S: The patient, a 12-year-old, reports having ...
# 36  S: The patient, a nonsmoker with no chronic di...
# 37  S: 50-year-old Chinese male presents with a on...
# 38  S: A 52-year-old female presented to the emerg...
# 39  S: The patient reports symptoms of dysphagia a...
# 40  S: The patient, a long-term heavy smoker, pres...
# 41  S: The mother reports a difficult pregnancy wi...
# 42  S: The patient is a 72-year-old female with st...
# 43  S: The patient, an unmarried office worker, re...
# 44  S: The patient reports experiencing limiting a...
# 45  S: 60-year-old white British female presents w...
# 46  S: The patient, with a history of hypertension...
# 47  S: The patient reports a 3-month history of ri...
# 48  S: The patient is a 36-year-old female with a ...
# 49  S: The patient, a young individual with no sig...
#
#                                     generated_summary  ROUGE-1  ROUGE-2  \
# 0   S: The patient, a flooring installer, reports ...   0.6339   0.3639
# 1   S: The patient is a 7-year-old boy with congen...   0.5355   0.2667
# 2   S: The patient reports a single thyroid nodule...   0.5597   0.2769
# 3   S: The patient reports a progressive headache,...   0.6597   0.3690
# 4   S: The patient, a patient with a history of ca...   0.5418   0.2760
# 5   S: The patient, a non-smoker, reports experien...   0.4755   0.2576
# 6   S: The patient, with a history of hypertension...   0.6120   0.3207
# 7   S: The patient reports a 6-month history of sw...   0.6473   0.4395
# 8   S: The patient, a prostate cancer patient, rep...   0.6810   0.3741
# 9   S: 76-year-old female patient reports a histor...   0.6261   0.3246
# 10  S: The patient, a mother of three children, re...   0.5869   0.2477
# 11  S: The patient is a 36-year-old Caucasian grav...   0.6656   0.4128
# 12  S: The patient reports difficulty walking for ...   0.6367   0.3137
# 13  S: The patient reports persistent pain in the ...   0.6545   0.4178
# 14  S: The patient, a 50-year-old African American...   0.7118   0.4739
# 15  S: The patient is a 53-year-old female with a ...   0.6577   0.4163
# 16  S: The patient, a 70-year-old woman, reports e...   0.6947   0.3710
# 17  S: The patient, a 64-year-old postmenopausal w...   0.5922   0.3345
# 18  S: The patient reports intermittent pain and s...   0.6061   0.3767
# 19  S: The patient, an infant, reports difficulty ...   0.4373   0.1679
# 20  S: The patient, a patient with a history of li...   0.5316   0.2582
# 21  S: The patient reports a four-day history of f...   0.5389   0.2743
# 22  S: The patient, a male with a history of invas...   0.7026   0.4208
# 23  S: The patient, a former morbidly obese patien...   0.5981   0.3317
# 24  S: The patient, a patient with a history of be...   0.6616   0.3473
# 25  S: The patient reports a week-long history of ...   0.5458   0.2427
# 26  S: The patient, a former bariatric surgery pat...   0.5490   0.2276
# 27  S: The mother, a 29-year-old European-born mot...   0.5810   0.2416
# 28  S: The patient, a 48-year-old female, reports ...   0.6684   0.4271
# 29  S: The patient, a male with a history of recur...   0.6076   0.3051
# 30  S: The patient, a cystic fibrosis patient with...   0.6047   0.2983
# 31  S: The patient reports a two-month history of ...   0.5739   0.3004
# 32  S: The patient, a woman with a history of obst...   0.5438   0.3065
# 33  S: The patient, a non-consanguineous Caucasian...   0.5553   0.2825
# 34  S: The patient, a male with a history of kidne...   0.5854   0.3202
# 35  S: 12-year-old male presented with a fever, ab...   0.6316   0.3558
# 36  S: The patient, a nonsmoker, reports worsening...   0.6534   0.3240
# 37  S: The patient, a 50-year-old Chinese man, pre...   0.5996   0.3253
# 38  S: The patient, a 52-year-old female, presents...   0.6610   0.3496
# 39  S: The patient, a male with a height of 158.0 ...   0.6186   0.3319
# 40  S: The patient, a heavy smoker for 20 years, r...   0.6059   0.3295
# 41  S: The mother, a first cousin of the father, r...   0.5909   0.2667
# 42  S: 72-year-old female melanoma patient present...   0.5906   0.3636
# 43  S: The patient, an unmarried office worker, re...   0.6626   0.4476
# 44  S: The patient reports a history of coronary a...   0.6302   0.3656
# 45  S: The patient, a 60-year-old white British fe...   0.4825   0.2383
# 46  S: The patient, a hypertension, diabetes, and ...   0.6163   0.3361
# 47  S: The patient reports a history of right knee...   0.5607   0.3114
# 48  S: 36-year-old female with a weight of 50 kg a...   0.5691   0.2153
# 49  S: The patient, a male, presented with a seizu...   0.6259   0.2982
#
#     ROUGE-L  ROUGE-LSum  BERTScore-P  BERTScore-R  BERTScore-F1  BLEURT
# 0    0.4508      0.5051       0.9129       0.8745        0.8933  0.2745
# 1    0.4265      0.4597       0.8601       0.8944        0.8769  0.2165
# 2    0.3416      0.4239       0.8967       0.8810        0.8888 -0.2875
# 3    0.4676      0.4969       0.8959       0.9097        0.9027  0.3832
# 4    0.2948      0.4263       0.8943       0.8745        0.8843 -0.1018
# 5    0.3509      0.3925       0.8358       0.8738        0.8544 -0.0998
# 6    0.3459      0.4656       0.9014       0.8898        0.8955 -0.0170
# 7    0.5045      0.5446       0.9266       0.8950        0.9106  0.1388
# 8    0.4659      0.5054       0.9299       0.9090        0.9193  0.0043
# 9    0.4104      0.4765       0.8938       0.8998        0.8968  0.1738
# 10   0.3439      0.4187       0.9049       0.8835        0.8941  0.0120
# 11   0.5184      0.5418       0.9141       0.9129        0.9135 -0.1605
# 12   0.4102      0.4531       0.9162       0.8926        0.9043 -0.2584
# 13   0.4935      0.5247       0.9121       0.9154        0.9137  0.2811
# 14   0.5575      0.5827       0.9258       0.9112        0.9184  0.0229
# 15   0.4595      0.5225       0.9260       0.9183        0.9221 -0.0598
# 16   0.4752      0.5263       0.9098       0.8926        0.9011  0.0323
# 17   0.4539      0.4823       0.8863       0.8942        0.8902  0.1452
# 18   0.4518      0.4628       0.9339       0.9033        0.9183  0.2356
# 19   0.3292      0.3882       0.8824       0.8708        0.8766 -0.3683
# 20   0.3312      0.4139       0.8989       0.8669        0.8826  0.0506
# 21   0.3833      0.4061       0.9089       0.8708        0.8894 -0.4209
# 22   0.4631      0.5469       0.9276       0.9014        0.9143 -0.0607
# 23   0.3445      0.3971       0.9031       0.8806        0.8917 -0.0814
# 24   0.4449      0.4829       0.9008       0.9044        0.9026 -0.1998
# 25   0.4055      0.4561       0.8855       0.8604        0.8728 -0.2138
# 26   0.3312      0.3704       0.8843       0.9047        0.8944 -0.0082
# 27   0.2905      0.4078       0.8928       0.8964        0.8946 -0.2473
# 28   0.5544      0.5751       0.9377       0.9079        0.9226  0.3257
# 29   0.3840      0.4641       0.9179       0.8825        0.8998  0.1270
# 30   0.4291      0.4459       0.8986       0.8632        0.8806 -0.0892
# 31   0.3908      0.4120       0.8833       0.8843        0.8838 -0.1971
# 32   0.3762      0.4209       0.8966       0.8842        0.8903 -0.1671
# 33   0.3002      0.4128       0.8824       0.8689        0.8756 -0.1055
# 34   0.3940      0.4465       0.9108       0.8802        0.8952 -0.1398
# 35   0.4258      0.4880       0.9074       0.9182        0.9127  0.0023
# 36   0.4343      0.4422       0.9144       0.8987        0.9065 -0.0622
# 37   0.4814      0.5164       0.8976       0.8939        0.8957  0.1762
# 38   0.5014      0.5128       0.9363       0.9088        0.9223 -0.0456
# 39   0.4449      0.4831       0.9061       0.8977        0.9019 -0.1467
# 40   0.4237      0.4920       0.9132       0.8973        0.9052 -0.2772
# 41   0.3881      0.4545       0.8967       0.8769        0.8867 -0.1944
# 42   0.4449      0.4685       0.9072       0.8634        0.8847 -0.0959
# 43   0.4867      0.5031       0.9226       0.8951        0.9086 -0.4205
# 44   0.4299      0.4444       0.9003       0.8846        0.8924 -0.2360
# 45   0.3074      0.3930       0.8899       0.8445        0.8666  0.3909
# 46   0.4367      0.4531       0.9069       0.8995        0.9032  0.2440
# 47   0.3888      0.4374       0.8846       0.8877        0.8862  0.2727
# 48   0.2829      0.3577       0.8731       0.8744        0.8738 -0.3394
# 49   0.3776      0.4266       0.9097       0.8930        0.9012 -0.3112

# %%
def calculate_average_metrics(df):
    metrics = [
        'ROUGE-1', 'ROUGE-2', 'ROUGE-L', 'ROUGE-LSum',
        'BERTScore-P', 'BERTScore-R', 'BERTScore-F1', 'BLEURT'
    ]
    avg_scores = {metric: df[metric].mean() for metric in metrics}
    return avg_scores

# %%
def display_evaluation(average_scores):
    print("Average Evaluation Metrics:")
    for metric, score in average_scores.items():
        print(f"{metric}: {score:.4f}")

# %%
eval_test_soap = calculate_average_metrics(eval_test_soap_50_df) # modified soap summary

# %%
display_evaluation(eval_test_soap)
# Out:
# Average Evaluation Metrics:
# ROUGE-1: 0.6033
# ROUGE-2: 0.3249
# ROUGE-L: 0.4126
# ROUGE-LSum: 0.4626
# BERTScore-P: 0.9031
# BERTScore-R: 0.8897
# BERTScore-F1: 0.8963
# BLEURT: -0.0381
